# %% [markdown]
# # Hospital Readmission Prediction — XGBoost + SHAP
#
# **Dataset:** UCI Diabetes 130-US Hospitals (Brandao, Kaggle)
# **Task:** 3-class readmission prediction — No Readmit (0) / >30 Days (1) / <30 Days (2)
# **Model:** XGBoost with hyperparameter tuning + SHAP explainability
# **Reference paper:** Rafie et al. (2025) — *Leveraging XGBoost and Explainable AI for Accurate Prediction of Type 2 Diabetes*, BMC Public Health
# **Paper 2:** Dharmarathne et al. (2024) — *A Novel Machine Learning Approach for Diagnosing Diabetes with a Self-Explainable Interface*, Healthcare Analytics
#
# ---
# **Pipeline:**
# Data Loading → Preprocessing → EDA → Feature Engineering/Selection → Model Training → Evaluation → Learning/Validation Curves → SHAP Explainability

# %% [markdown]
# # **1-Load Needed Libraries and Preproccessing**
#
# ---
#
#
#
# ---

# %%
import kagglehub
import os
import math
import json
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shap

from xgboost import XGBClassifier
from sklearn.model_selection import (
    train_test_split, learning_curve, validation_curve
)
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, roc_auc_score
)

path = kagglehub.dataset_download('brandao/diabetes')
print('Path to dataset files:', path)

file_path = os.path.join(path, [f for f in os.listdir(path) if f.endswith('.csv')][0])
df = pd.read_csv(file_path)
print('Original dataset shape:', df.shape)
df
# Out:
# Using Colab cache for faster access to the 'diabetes' dataset.
# Path to dataset files: /kaggle/input/diabetes
# Original dataset shape: (101766, 50)
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# 1                       1                         1                    7
# 2                       1                         1                    7
# 3                       1                         1                    7
# 4                       1                         1                    7
# ...                   ...                       ...                  ...
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                      1  ...          No      No                   No
# 1                      3  ...          No      Up                   No
# 2                      2  ...          No      No                   No
# 3                      2  ...          No      Up                   No
# 4                      1  ...          No  Steady                   No
# ...                  ...  ...         ...     ...                  ...
# 101761                 3  ...          No    Down                   No
# 101762                 5  ...          No  Steady                   No
# 101763                 1  ...          No    Down                   No
# 101764                10  ...          No      Up                   No
# 101765                 6  ...          No      No                   No
#
#         glipizide-metformin  glimepiride-pioglitazone  \
# 0                        No                        No
# 1                        No                        No
# 2                        No                        No
# 3                        No                        No
# 4                        No                        No
# ...                     ...                       ...
# 101761                   No                        No
# 101762                   No                        No
# 101763                   No                        No
# 101764                   No                        No
# 101765                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone  change diabetesMed  \
# 0                            No                      No      No          No
# 1                            No                      No      Ch         Yes
# 2                            No                      No      No         Yes
# 3                            No                      No      Ch         Yes
# 4                            No                      No      Ch         Yes
# ...                         ...                     ...     ...         ...
# 101761                       No                      No      Ch         Yes
# 101762                       No                      No      No         Yes
# 101763                       No                      No      Ch         Yes
# 101764                       No                      No      Ch         Yes
# 101765                       No                      No      No          No
#
#        readmitted
# 0              NO
# 1             >30
# 2              NO
# 3              NO
# 4              NO
# ...           ...
# 101761        >30
# 101762         NO
# 101763         NO
# 101764         NO
# 101765         NO
#
# [101766 rows x 50 columns]

# %%
df["weight"].value_counts()
# Out:
# weight
# ?            98569
# [75-100)      1336
# [50-75)        897
# [100-125)      625
# [125-150)      145
# [25-50)         97
# [0-25)          48
# [150-175)       35
# [175-200)       11
# >200             3
# Name: count, dtype: int64

# %%
df["payer_code"].value_counts()
# Out:
# payer_code
# ?     40256
# MC    32439
# HM     6274
# SP     5007
# BC     4655
# MD     3532
# CP     2533
# UN     2448
# CM     1937
# OG     1033
# PO      592
# DM      549
# CH      146
# WC      135
# OT       95
# MP       79
# SI       55
# FR        1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                            0
# gender                          0
# age                             0
# weight                          0
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                      0
# medical_specialty               0
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                          0
# diag_2                          0
# diag_3                          0
# number_diagnoses                0
# max_glu_serum               96420
# A1Cresult                   84748
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# chlorpropamide                  0
# glimepiride                     0
# acetohexamide                   0
# glipizide                       0
# glyburide                       0
# tolbutamide                     0
# pioglitazone                    0
# rosiglitazone                   0
# acarbose                        0
# miglitol                        0
# troglitazone                    0
# tolazamide                      0
# examide                         0
# citoglipton                     0
# insulin                         0
# glyburide-metformin             0
# glipizide-metformin             0
# glimepiride-pioglitazone        0
# metformin-rosiglitazone         0
# metformin-pioglitazone          0
# change                          0
# diabetesMed                     0
# readmitted                      0
# dtype: int64

# %%
df = df[df['race'] != '?']
df = df[df['gender'] != 'Unknown/Invalid']

# %%
def map_discharge(x):
    if x == 1:
        return "Home"
    elif x in [3, 6]:
        return "Care"
    elif x == 2:
        return "Transfer"
    elif x in [11, 19, 20, 21]:
        return "Death"
    elif x in [13, 14]:
        return "Hospice"
    elif x == 18:
        return "Unknown"
    else:
        return "Other"

df['discharge_group'] = df['discharge_disposition_id'].apply(map_discharge)
df = df[df['discharge_group'] != 'Unknown']

# %%
df_c = df.drop(columns=[
    'discharge_disposition_id',
    'metformin-pioglitazone',
    'glyburide-metformin',
    'glimepiride-pioglitazone',
    'encounter_id',
    'patient_nbr',
    'weight',
    'max_glu_serum',
    'A1Cresult',
    'payer_code',
    'medical_specialty',
    'glipizide-metformin',
    'metformin-rosiglitazone',
    'examide',
    'citoglipton',
    'acetohexamide',
    'troglitazone',
    'tolbutamide',
    'tolazamide',
    'chlorpropamide', 'miglitol', 'acarbose',
    'nateglinide', 'repaglinide'
])

df_c.shape
# Out:
# (95819, 27)

# %%
def map_icd9(code):
    try:
        c = str(code).strip()
        if c.startswith('V'): return 'Supplementary'
        if c.startswith('E'): return 'External_Causes'
        n = float(c)
        if n < 140:  return 'Infectious'
        if n < 240:  return 'Neoplasms'
        if n < 280:  return 'Endocrine_Diabetes'
        if n < 290:  return 'Blood'
        if n < 320:  return 'Mental'
        if n < 360:  return 'Nervous_System'
        if n < 390:  return 'Sensory'
        if n < 460:  return 'Circulatory'
        if n < 520:  return 'Respiratory'
        if n < 580:  return 'Digestive'
        if n < 630:  return 'Genitourinary'
        if n < 680:  return 'Pregnancy'
        if n < 710:  return 'Skin'
        if n < 740:  return 'Musculoskeletal'
        if n < 760:  return 'Congenital'
        if n < 780:  return 'Perinatal'
        if n < 800:  return 'Symptoms'
        return 'Injury'
    except:
        return 'Other'

df_c['diag_1'] = df_c['diag_1'].apply(map_icd9)
df_c['diag_2'] = df_c['diag_2'].apply(map_icd9)
df_c['diag_3'] = df_c['diag_3'].apply(map_icd9)

# %%
df_c.isnull().sum().sum()
df_c.duplicated().sum()
df_c.drop_duplicates(inplace=True)

# %%
# 0 → Will not return
# 1 → Will return after a long time
# 2 → Will return soon (dangerous)
readmit_map = {'NO': 0, '>30': 1, '<30': 2}
df_c['readmitted'] = df_c['readmitted'].map(readmit_map)

df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95818 entries, 0 to 101765
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   race                 95818 non-null  object
#  1   gender               95818 non-null  object
#  2   age                  95818 non-null  object
#  3   admission_type_id    95818 non-null  int64
#  4   admission_source_id  95818 non-null  int64
#  5   time_in_hospital     95818 non-null  int64
#  6   num_lab_procedures   95818 non-null  int64
#  7   num_procedures       95818 non-null  int64
#  8   num_medications      95818 non-null  int64
#  9   number_outpatient    95818 non-null  int64
#  10  number_emergency     95818 non-null  int64
#  11  number_inpatient     95818 non-null  int64
#  12  diag_1               95818 non-null  object
#  13  diag_2               95818 non-null  object
#  14  diag_3               95818 non-null  object
#  15  number_diagnoses     95818 non-null  int64
#  16  metformin            95818 non-null  object
#  17  glimepiride          95818 non-null  object
#  18  glipizide            95818 non-null  object
#  19  glyburide            95818 non-null  object
#  20  pioglitazone         95818 non-null  object
#  21  rosiglitazone        95818 non-null  object
#  22  insulin              95818 non-null  object
#  23  change               95818 non-null  object
#  24  diabetesMed          95818 non-null  object
#  25  readmitted           95818 non-null  int64
#  26  discharge_group      95818 non-null  object
# dtypes: int64(11), object(16)
# memory usage: 20.5+ MB

# %%
df_num = df_c.select_dtypes(include=np.number)

# %% [markdown]
# #**Step 2: EDA**
# ----------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------

# %%
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = [10, 6]

sns.set_theme(style="darkgrid", rc={
    "axes.facecolor": "#242424",
    "figure.facecolor": "#1c1c1c",
    "grid.color": "#444444",
    "text.color": "white",
    "axes.labelcolor": "white",
    "xtick.color": "white",
    "ytick.color": "white"
})

plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df_c, x='readmitted', palette='spring')
plt.title('Distribution of Readmission Events', color='white', fontsize=14, pad=15)
ax.set_xticklabels(['No Readmit', '>30 Days', '<30 Days'])
plt.show()
# Out:
# /tmp/ipykernel_3420/3298773600.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df_c, x='readmitted', palette='spring')
# /tmp/ipykernel_3420/3298773600.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['No Readmit', '>30 Days', '<30 Days'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid", rc={
    "axes.facecolor": "#242424",
    "figure.facecolor": "#1c1c1c",
    "grid.color": "#444444",
    "text.color": "white",
    "axes.labelcolor": "white",
    "xtick.color": "white",
    "ytick.color": "white"
})

plt.figure(figsize=(12, 6))
ax = sns.countplot(data=df_c, x='age', hue='readmitted', palette='viridis')
plt.title('Readmission Count by Age Group', color='white', fontsize=14, pad=15)
plt.xlabel('Age Group (0: Youngest → 9: Oldest)', color='white')
plt.ylabel('Count', color='white')
legend = plt.legend(title='Readmitted Status', labels=['No', '>30', '<30'],
                    facecolor='#242424', edgecolor='white')
plt.setp(legend.get_texts(), color='white')
plt.setp(legend.get_title(), color='white')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df_c, x='insulin', hue='readmitted', palette='coolwarm')
plt.title('Insulin Dosage Changes vs. Readmission')
plt.xticks([0, 1, 2, 3], ['No', 'Steady', 'Down', 'Up'])
plt.show()

# %%
fig, axes = plt.subplots(nrows=6, ncols=2, figsize=(15, 22))
fig.set_facecolor('#0f1117')
axes_flat = axes.flatten()

for i, col in enumerate(df_num):
    if i >= len(axes_flat):
        break
    ax = axes_flat[i]
    ax.set_facecolor('#0f1117')
    skew_val = df_c[col].skew()
    sns.histplot(df_c[col], kde=True, color='#4FC3F7', edgecolor='none', ax=ax)
    ax.set_title(f"Feature: {col}\nSkewness = {skew_val:.2f}",
                 fontsize=12, color='white', fontweight='bold', pad=10)
    ax.set_xlabel("Value", fontsize=10, color='#e0e0e0')
    ax.set_ylabel("Frequency", fontsize=10, color='#e0e0e0')
    ax.grid(True, linestyle=':', alpha=0.2, color='white')
    ax.tick_params(colors='white')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle("Distribution and Skewness of Numeric Features", color='white', fontsize=20, fontweight='bold')
plt.show()

# %%
cols_to_fix = ['number_emergency', 'number_outpatient', 'number_inpatient',
               'num_medications', 'time_in_hospital', 'num_lab_procedures']

for col in cols_to_fix:
    df_c[col] = np.log1p(df_c[col])

print('Skewness after Log Transformation:')
print(df_c[cols_to_fix].skew())
# Out:
# Skewness after Log Transformation:
# number_emergency      3.546373
# number_outpatient     2.668303
# number_inpatient      1.433748
# num_medications      -0.499344
# time_in_hospital      0.111122
# num_lab_procedures   -2.192645
# dtype: float64

# %%
cols_to_fix = ['number_emergency', 'number_outpatient', 'number_inpatient',
               'num_medications', 'time_in_hospital', 'num_lab_procedures']

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))
fig.set_facecolor('#0f1117')
axes_flat = axes.flatten()

for i, col in enumerate(cols_to_fix):
    ax = axes_flat[i]
    ax.set_facecolor('#0f1117')
    skew_val = df_c[col].skew()
    sns.histplot(df_c[col], kde=True, color='#4FC3F7', edgecolor='none', ax=ax)
    ax.set_title(f'Feature: {col} (Log Transformed)\nSkewness = {skew_val:.2f}',
                 fontsize=12, color='white', fontweight='bold', pad=10)
    ax.set_xlabel('Log Value', fontsize=10, color='#e0e0e0')
    ax.set_ylabel('Frequency', fontsize=10, color='#e0e0e0')
    ax.grid(True, linestyle=':', alpha=0.2, color='white')
    ax.tick_params(colors='white')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.suptitle('Post-Transformation Distribution (Log Scale)', color='white',
             fontsize=20, fontweight='bold')
plt.show()

# %%
sns.set_theme(style="darkgrid", rc={
    "axes.facecolor": "#242424",
    "figure.facecolor": "#1c1c1c",
    "grid.color": "#444444",
    "text.color": "white",
    "axes.labelcolor": "white",
    "xtick.color": "white",
    "ytick.color": "white"
})

fig, axes = plt.subplots(nrows=6, ncols=2, figsize=(15, 20))
fig.subplots_adjust(hspace=0.4, wspace=0.3)
fig.suptitle('Outliers Analysis for All Numeric Features', color='white', fontsize=20, y=0.92)
axes_flat = axes.flatten()

for i, col in enumerate(df_num):
    ax = axes_flat[i]
    sns.boxplot(x=df_c[col], ax=ax, color='#00e5ff', fliersize=4)
    plt.setp(ax.artists, edgecolor="white", linewidth=1.5)
    plt.setp(ax.lines, color="white", linewidth=1.5)
    ax.set_title(f'Feature: {col}', color='yellow', fontsize=12)
    ax.set_xlabel('')

for j in range(i + 1, len(axes_flat)):
    axes_flat[j].axis('off')

plt.show()

# %%
print(f"{'Feature':<25} | {'Outliers Count':<15} | {'Percentage':<10}")
print("-" * 55)
total_rows = len(df_c)

for col in df_num:
    Q1 = df_c[col].quantile(0.25)
    Q3 = df_c[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df_c[(df_c[col] < lower_bound) | (df_c[col] > upper_bound)]
    count = len(outliers)
    percentage = (count / total_rows) * 100
    print(f"{col:<25} | {count:<15} | {percentage:.2f}%")
# Out:
# Feature                   | Outliers Count  | Percentage
# -------------------------------------------------------
# admission_type_id         | 337             | 0.35%
# admission_source_id       | 6866            | 7.17%
# time_in_hospital          | 0               | 0.00%
# num_lab_procedures        | 9246            | 9.65%
# num_procedures            | 4582            | 4.78%
# num_medications           | 1770            | 1.85%
# number_outpatient         | 16389           | 17.10%
# number_emergency          | 11272           | 11.76%
# number_inpatient          | 1960            | 2.05%
# number_diagnoses          | 261             | 0.27%
# readmitted                | 0               | 0.00%

# %%
safe_cols_to_clean = [ 'num_lab_procedures', 'num_medications', 'number_diagnoses', 'time_in_hospital']
print(f"Original shape: {df_c.shape}")

for col in safe_cols_to_clean:
    Q1 = df_c[col].quantile(0.25)
    Q3 = df_c[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_c = df_c[(df_c[col] >= lower_bound) & (df_c[col] <= upper_bound)]

print(f"Fixed shape: {df_c.shape}")
# Out:
# Original shape: (95818, 27)
# Fixed shape: (84886, 27)

# %%
print(f"{'Feature':<25} | {'Outliers Count':<15} | {'Percentage':<10}")
print("-" * 55)
total_rows = len(df_c)

for col in df_num:
    Q1 = df_c[col].quantile(0.25)
    Q3 = df_c[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df_c[(df_c[col] < lower_bound) | (df_c[col] > upper_bound)]
    count = len(outliers)
    percentage = (count / total_rows) * 100
    print(f"{col:<25} | {count:<15} | {percentage:.2f}%")
# Out:
# Feature                   | Outliers Count  | Percentage
# -------------------------------------------------------
# admission_type_id         | 286             | 0.34%
# admission_source_id       | 6026            | 7.10%
# time_in_hospital          | 0               | 0.00%
# num_lab_procedures        | 1639            | 1.93%
# num_procedures            | 4131            | 4.87%
# num_medications           | 0               | 0.00%
# number_outpatient         | 14325           | 16.88%
# number_emergency          | 10104           | 11.90%
# number_inpatient          | 1800            | 2.12%
# number_diagnoses          | 0               | 0.00%
# readmitted                | 0               | 0.00%

# %%
corr_matrix = df_num.corr()

plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, cmap='coolwarm', center=0, annot=True,
            fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix (Numeric Features Only)")
plt.show()

corr_with_target = corr_matrix['readmitted'].sort_values(ascending=False)
print(corr_with_target)
# need to drop  admission_type_id  &&  num_procedures
# Out:
# readmitted             1.000000
# number_inpatient       0.233497
# number_emergency       0.104288
# number_diagnoses       0.100961
# number_outpatient      0.067485
# time_in_hospital       0.057634
# num_medications        0.054058
# num_lab_procedures     0.036428
# admission_source_id    0.028534
# admission_type_id     -0.008632
# num_procedures        -0.036341
# Name: readmitted, dtype: float64

# %% [markdown]
# #**Feature Engineering/Selection**
# ----------------------------------------------------------------------------------------
# --------------------------------------------------------------------

# %%
age_dummies = pd.get_dummies(
    df_c['age'],
    prefix='age',
    drop_first=False
)

age_dummies = age_dummies.astype(int)

df_c = df_c.drop(columns=['age'])
df_c = pd.concat([df_c, age_dummies], axis=1)

# %%
df_c = df_c.drop(columns=['admission_type_id', 'num_procedures'])

# %%
cat_cols = ['race', 'gender', 'change', 'diabetesMed',
            'discharge_group', 'diag_1', 'diag_2', 'diag_3']
df_c = pd.get_dummies(df_c, columns=cat_cols, drop_first=True)

# %%
df_c['admission_source_id'] = df_c['admission_source_id'].astype(str)
df_c = pd.get_dummies(df_c, columns=['admission_source_id'], drop_first=True)

# %%
drop_cols = [
    'admission_source_id_8',
    'admission_source_id_9',
    'admission_source_id_10',
    'admission_source_id_11',
    'admission_source_id_13',
    'admission_source_id_14',
    'admission_source_id_22',
    'admission_source_id_25',
    'diag_1_External_Causes',
    'diag_1_Other',
    'diag_1_Congenital',
    'diag_2_Congenital',
    'diag_3_Congenital',
]
# errors='ignore' silently skips any column that doesn't exist in this run
df_c = df_c.drop(columns=drop_cols, errors='ignore')

# %%
cats = df_c.select_dtypes(include='object').columns.tolist()
for col in cats:
    print(col, df_c[col].unique())
# Out:
# metformin ['No' 'Steady' 'Up' 'Down']
# glimepiride ['No' 'Steady' 'Down' 'Up']
# glipizide ['No' 'Steady' 'Up' 'Down']
# glyburide ['No' 'Steady' 'Up' 'Down']
# pioglitazone ['No' 'Steady' 'Up' 'Down']
# rosiglitazone ['No' 'Steady' 'Up' 'Down']
# insulin ['Up' 'Steady' 'No' 'Down']

# %%
med_map = {'No': 0, 'Steady': 1, 'Down': 2, 'Up': 3}
med_cols = ['metformin','glimepiride','glipizide',
            'glyburide','pioglitazone','rosiglitazone','insulin']
for col in med_cols:
    df_c[col] = df_c[col].map(med_map)

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84886 entries, 1 to 101764
# Data columns (total 97 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time_in_hospital           84886 non-null  float64
#  1   num_lab_procedures         84886 non-null  float64
#  2   num_medications            84886 non-null  float64
#  3   number_outpatient          84886 non-null  float64
#  4   number_emergency           84886 non-null  float64
#  5   number_inpatient           84886 non-null  float64
#  6   number_diagnoses           84886 non-null  int64
#  7   metformin                  84886 non-null  int64
#  8   glimepiride                84886 non-null  int64
#  9   glipizide                  84886 non-null  int64
#  10  glyburide                  84886 non-null  int64
#  11  pioglitazone               84886 non-null  int64
#  12  rosiglitazone              84886 non-null  int64
#  13  insulin                    84886 non-null  int64
#  14  readmitted                 84886 non-null  int64
#  15  age_[0-10)                 84886 non-null  int64
#  16  age_[10-20)                84886 non-null  int64
#  17  age_[20-30)                84886 non-null  int64
#  18  age_[30-40)                84886 non-null  int64
#  19  age_[40-50)                84886 non-null  int64
#  20  age_[50-60)                84886 non-null  int64
#  21  age_[60-70)                84886 non-null  int64
#  22  age_[70-80)                84886 non-null  int64
#  23  age_[80-90)                84886 non-null  int64
#  24  age_[90-100)               84886 non-null  int64
#  25  race_Asian                 84886 non-null  bool
#  26  race_Caucasian             84886 non-null  bool
#  27  race_Hispanic              84886 non-null  bool
#  28  race_Other                 84886 non-null  bool
#  29  gender_Male                84886 non-null  bool
#  30  change_No                  84886 non-null  bool
#  31  diabetesMed_Yes            84886 non-null  bool
#  32  discharge_group_Death      84886 non-null  bool
#  33  discharge_group_Home       84886 non-null  bool
#  34  discharge_group_Hospice    84886 non-null  bool
#  35  discharge_group_Other      84886 non-null  bool
#  36  discharge_group_Transfer   84886 non-null  bool
#  37  diag_1_Circulatory         84886 non-null  bool
#  38  diag_1_Digestive           84886 non-null  bool
#  39  diag_1_Endocrine_Diabetes  84886 non-null  bool
#  40  diag_1_Genitourinary       84886 non-null  bool
#  41  diag_1_Infectious          84886 non-null  bool
#  42  diag_1_Injury              84886 non-null  bool
#  43  diag_1_Mental              84886 non-null  bool
#  44  diag_1_Musculoskeletal     84886 non-null  bool
#  45  diag_1_Neoplasms           84886 non-null  bool
#  46  diag_1_Nervous_System      84886 non-null  bool
#  47  diag_1_Pregnancy           84886 non-null  bool
#  48  diag_1_Respiratory         84886 non-null  bool
#  49  diag_1_Sensory             84886 non-null  bool
#  50  diag_1_Skin                84886 non-null  bool
#  51  diag_1_Supplementary       84886 non-null  bool
#  52  diag_1_Symptoms            84886 non-null  bool
#  53  diag_2_Circulatory         84886 non-null  bool
#  54  diag_2_Digestive           84886 non-null  bool
#  55  diag_2_Endocrine_Diabetes  84886 non-null  bool
#  56  diag_2_External_Causes     84886 non-null  bool
#  57  diag_2_Genitourinary       84886 non-null  bool
#  58  diag_2_Infectious          84886 non-null  bool
#  59  diag_2_Injury              84886 non-null  bool
#  60  diag_2_Mental              84886 non-null  bool
#  61  diag_2_Musculoskeletal     84886 non-null  bool
#  62  diag_2_Neoplasms           84886 non-null  bool
#  63  diag_2_Nervous_System      84886 non-null  bool
#  64  diag_2_Other               84886 non-null  bool
#  65  diag_2_Pregnancy           84886 non-null  bool
#  66  diag_2_Respiratory         84886 non-null  bool
#  67  diag_2_Sensory             84886 non-null  bool
#  68  diag_2_Skin                84886 non-null  bool
#  69  diag_2_Supplementary       84886 non-null  bool
#  70  diag_2_Symptoms            84886 non-null  bool
#  71  diag_3_Circulatory         84886 non-null  bool
#  72  diag_3_Digestive           84886 non-null  bool
#  73  diag_3_Endocrine_Diabetes  84886 non-null  bool
#  74  diag_3_External_Causes     84886 non-null  bool
#  75  diag_3_Genitourinary       84886 non-null  bool
#  76  diag_3_Infectious          84886 non-null  bool
#  77  diag_3_Injury              84886 non-null  bool
#  78  diag_3_Mental              84886 non-null  bool
#  79  diag_3_Musculoskeletal     84886 non-null  bool
#  80  diag_3_Neoplasms           84886 non-null  bool
#  81  diag_3_Nervous_System      84886 non-null  bool
#  82  diag_3_Other               84886 non-null  bool
#  83  diag_3_Pregnancy           84886 non-null  bool
#  84  diag_3_Respiratory         84886 non-null  bool
#  85  diag_3_Sensory             84886 non-null  bool
#  86  diag_3_Skin                84886 non-null  bool
#  87  diag_3_Supplementary       84886 non-null  bool
#  88  diag_3_Symptoms            84886 non-null  bool
#  89  admission_source_id_17     84886 non-null  bool
#  90  admission_source_id_2      84886 non-null  bool
#  91  admission_source_id_20     84886 non-null  bool
#  92  admission_source_id_3      84886 non-null  bool
#  93  admission_source_id_4      84886 non-null  bool
#  94  admission_source_id_5      84886 non-null  bool
#  95  admission_source_id_6      84886 non-null  bool
#  96  admission_source_id_7      84886 non-null  bool
# dtypes: bool(72), float64(6), int64(19)
# memory usage: 22.7 MB

# %%
for col in df_c.columns:
    print("="*50)
    print(f"Column: {col}")
    print("-"*50)
    print(df_c[col].value_counts(dropna=False))
    print("\n")
# Out:
# ==================================================
# Column: time_in_hospital
# --------------------------------------------------
# time_in_hospital
# 1.386294    14708
# 1.098612    13823
# 1.609438    12035
# 0.693147    10452
# 1.791759     8753
# 1.945910     6620
# 2.079442     5173
# 2.197225     3831
# 2.302585     2637
# 2.397895     2037
# 2.484907     1624
# 2.564949     1255
# 2.639057     1042
# 2.708050      896
# Name: count, dtype: int64
#
#
# ==================================================
# Column: num_lab_procedures
# --------------------------------------------------
# num_lab_procedures
# 3.784190    2560
# 3.806662    2280
# 3.828641    2179
# 3.663562    2038
# 3.850148    2017
#             ...
# 4.795791       1
# 4.890349       1
# 4.804021       1
# 4.844187       1
# 4.779123       1
# Name: count, Length: 106, dtype: int64
#
#
# ==================================================
# Column: num_medications
# --------------------------------------------------
# num_medications
# 2.639057    5070
# 2.564949    4969
# 2.772589    4963
# 2.708050    4840
# 2.484907    4727
# 2.833213    4671
# 2.397895    4388
# 2.890372    4271
# 2.944439    3973
# 2.302585    3929
# 2.995732    3569
# 2.197225    3460
# 3.044522    3286
# 3.091042    2891
# 2.079442    2708
# 3.135494    2585
# 3.178054    2203
# 1.945910    2075
# 3.218876    1919
# 3.258097    1736
# 1.791759    1517
# 3.295837    1470
# 3.332205    1330
# 3.367296    1127
# 1.609438    1056
# 3.401197     903
# 3.433987     777
# 3.465736     662
# 3.496508     580
# 3.526361     468
# 3.555348     417
# 3.583519     360
# 3.610918     265
# 3.637586     263
# 3.663562     205
# 3.688879     193
# 3.713572     159
# 3.737670     119
# 3.761200     111
# 3.784190     103
# 3.806662      87
# 3.850148      77
# 3.828641      73
# 3.871201      64
# 3.912023      53
# 3.970292      48
# 3.891820      48
# 3.931826      45
# 3.951244      41
# 3.988984      32
# Name: count, dtype: int64
#
#
# ==================================================
# Column: number_outpatient
# --------------------------------------------------
# number_outpatient
# 0.000000    70561
# 0.693147     7236
# 1.098612     3101
# 1.386294     1767
# 1.609438      933
# 1.791759      462
# 1.945910      269
# 2.079442      139
# 2.197225       92
# 2.302585       71
# 2.397895       54
# 2.484907       38
# 2.564949       28
# 2.639057       27
# 2.708050       25
# 2.772589       20
# 2.833213       15
# 3.044522        6
# 3.135494        5
# 3.091042        4
# 2.944439        4
# 2.890372        3
# 3.332205        3
# 2.995732        3
# 3.401197        2
# 3.583519        2
# 3.218876        2
# 3.178054        2
# 3.526361        2
# 3.295837        2
# 3.555348        1
# 3.688879        1
# 3.610918        1
# 3.258097        1
# 3.367296        1
# 3.637586        1
# 3.663562        1
# 3.713572        1
# Name: count, dtype: int64
#
#
# ==================================================
# Column: number_emergency
# --------------------------------------------------
# number_emergency
# 0.000000    74782
# 0.693147     6813
# 1.098612     1816
# 1.386294      653
# 1.609438      332
# 1.791759      172
# 1.945910       79
# 2.079442       63
# 2.197225       47
# 2.397895       28
# 2.302585       24
# 2.484907       19
# 2.639057       11
# 2.564949        9
# 3.135494        5
# 2.833213        5
# 2.944439        4
# 2.995732        4
# 2.708050        3
# 3.044522        3
# 3.258097        2
# 3.091042        2
# 2.772589        2
# 3.761200        1
# 3.367296        1
# 4.343805        1
# 3.637586        1
# 4.158883        1
# 4.007333        1
# 3.218876        1
# 3.401197        1
# Name: count, dtype: int64
#
#
# ==================================================
# Column: number_inpatient
# --------------------------------------------------
# number_inpatient
# 0.000000    55504
# 0.693147    16620
# 1.098612     6580
# 1.386294     2964
# 1.609438     1418
# 1.791759      717
# 1.945910      440
# 2.079442      245
# 2.197225      131
# 2.302585       93
# 2.397895       56
# 2.484907       45
# 2.564949       27
# 2.639057       20
# 2.708050        9
# 2.772589        8
# 2.833213        5
# 2.995732        2
# 3.091042        1
# 2.944439        1
# Name: count, dtype: int64
#
#
# ==================================================
# Column: number_diagnoses
# --------------------------------------------------
# number_diagnoses
# 9     43191
# 8      8982
# 5      8898
# 7      8537
# 6      8202
# 4      4208
# 3      2098
# 2       731
# 13       14
# 10       12
# 12        7
# 11        6
# Name: count, dtype: int64
#
#
# ==================================================
# Column: metformin
# --------------------------------------------------
# metformin
# 0    68525
# 1    14963
# 3      915
# 2      483
# Name: count, dtype: int64
#
#
# ==================================================
# Column: glimepiride
# --------------------------------------------------
# glimepiride
# 0    80528
# 1     3905
# 3      283
# 2      170
# Name: count, dtype: int64
#
#
# ==================================================
# Column: glipizide
# --------------------------------------------------
# glipizide
# 0    74000
# 1     9722
# 3      673
# 2      491
# Name: count, dtype: int64
#
#
# ==================================================
# Column: glyburide
# --------------------------------------------------
# glyburide
# 0    76290
# 1     7458
# 3      672
# 2      466
# Name: count, dtype: int64
#
#
# ==================================================
# Column: pioglitazone
# --------------------------------------------------
# pioglitazone
# 0    78690
# 1     5875
# 3      218
# 2      103
# Name: count, dtype: int64
#
#
# ==================================================
# Column: rosiglitazone
# --------------------------------------------------
# rosiglitazone
# 0    79512
# 1     5141
# 3      159
# 2       74
# Name: count, dtype: int64
#
#
# ==================================================
# Column: insulin
# --------------------------------------------------
# insulin
# 0    37816
# 1    26315
# 2    10847
# 3     9908
# Name: count, dtype: int64
#
#
# ==================================================
# Column: readmitted
# --------------------------------------------------
# readmitted
# 0    44772
# 1    30442
# 2     9672
# Name: count, dtype: int64
#
#
# ==================================================
# Column: age_[0-10)
# --------------------------------------------------
# age_[0-10)
# 0    84795
# 1       91
# Name: count, dtype: int64
#
#
# ==================================================
# Column: age_[10-20)
# --------------------------------------------------
# age_[10-20)
# 0    84421
# 1      465
# Name: count, dtype: int64
#
#
# ==================================================
# Column: age_[20-30)
# --------------------------------------------------
# age_[20-30)
# 0    83551
# 1     1335
# Name: count, dtype: int64
#
#
# ==================================================
# Column: age_[30-40)
# --------------------------------------------------
# age_[30-40)
# 0    81762
# 1     3124
# Name: count, dtype: int64
#
#
# ==================================================
# Column: age_[40-50)
# --------------------------------------------------
# age_[40-50)
# 0    76959
# 1     7927
# Name: count, dtype: int64
#
#
# ==================================================
# Column: age_[50-60)
# --------------------------------------------------
# age_[50-60)
# 0    70496
# 1    14390
# Name: count, dtype: int64
#
#
# ==================================================
# Column: age_[60-70)
# --------------------------------------------------
# age_[60-70)
# 0    66179
# 1    18707
# Name: count, dtype: int64
#
#
# ==================================================
# Column: age_[70-80)
# --------------------------------------------------
# age_[70-80)
# 0    63099
# 1    21787
# Name: count, dtype: int64
#
#
# ==================================================
# Column: age_[80-90)
# --------------------------------------------------
# age_[80-90)
# 0    70227
# 1    14659
# Name: count, dtype: int64
#
#
# ==================================================
# Column: age_[90-100)
# --------------------------------------------------
# age_[90-100)
# 0    82485
# 1     2401
# Name: count, dtype: int64
#
#
# ==================================================
# Column: race_Asian
# --------------------------------------------------
# race_Asian
# False    84353
# True       533
# Name: count, dtype: int64
#
#
# ==================================================
# Column: race_Caucasian
# --------------------------------------------------
# race_Caucasian
# True     64881
# False    20005
# Name: count, dtype: int64
#
#
# ==================================================
# Column: race_Hispanic
# --------------------------------------------------
# race_Hispanic
# False    83232
# True      1654
# Name: count, dtype: int64
#
#
# ==================================================
# Column: race_Other
# --------------------------------------------------
# race_Other
# False    83614
# True      1272
# Name: count, dtype: int64
#
#
# ==================================================
# Column: gender_Male
# --------------------------------------------------
# gender_Male
# False    45796
# True     39090
# Name: count, dtype: int64
#
#
# ==================================================
# Column: change_No
# --------------------------------------------------
# change_No
# True     44543
# False    40343
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diabetesMed_Yes
# --------------------------------------------------
# diabetesMed_Yes
# True     66173
# False    18713
# Name: count, dtype: int64
#
#
# ==================================================
# Column: discharge_group_Death
# --------------------------------------------------
# discharge_group_Death
# False    83378
# True      1508
# Name: count, dtype: int64
#
#
# ==================================================
# Column: discharge_group_Home
# --------------------------------------------------
# discharge_group_Home
# True     51258
# False    33628
# Name: count, dtype: int64
#
#
# ==================================================
# Column: discharge_group_Hospice
# --------------------------------------------------
# discharge_group_Hospice
# False    84177
# True       709
# Name: count, dtype: int64
#
#
# ==================================================
# Column: discharge_group_Other
# --------------------------------------------------
# discharge_group_Other
# False    79258
# True      5628
# Name: count, dtype: int64
#
#
# ==================================================
# Column: discharge_group_Transfer
# --------------------------------------------------
# discharge_group_Transfer
# False    83011
# True      1875
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Circulatory
# --------------------------------------------------
# diag_1_Circulatory
# False    59770
# True     25116
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Digestive
# --------------------------------------------------
# diag_1_Digestive
# False    76837
# True      8049
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Endocrine_Diabetes
# --------------------------------------------------
# diag_1_Endocrine_Diabetes
# False    75563
# True      9323
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Genitourinary
# --------------------------------------------------
# diag_1_Genitourinary
# False    80529
# True      4357
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Infectious
# --------------------------------------------------
# diag_1_Infectious
# False    82380
# True      2506
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Injury
# --------------------------------------------------
# diag_1_Injury
# False    78957
# True      5929
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Mental
# --------------------------------------------------
# diag_1_Mental
# False    83157
# True      1729
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Musculoskeletal
# --------------------------------------------------
# diag_1_Musculoskeletal
# False    81111
# True      3775
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Neoplasms
# --------------------------------------------------
# diag_1_Neoplasms
# False    82046
# True      2840
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Nervous_System
# --------------------------------------------------
# diag_1_Nervous_System
# False    84119
# True       767
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Pregnancy
# --------------------------------------------------
# diag_1_Pregnancy
# False    84351
# True       535
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Respiratory
# --------------------------------------------------
# diag_1_Respiratory
# False    75732
# True      9154
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Sensory
# --------------------------------------------------
# diag_1_Sensory
# False    84682
# True       204
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Skin
# --------------------------------------------------
# diag_1_Skin
# False    82683
# True      2203
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Supplementary
# --------------------------------------------------
# diag_1_Supplementary
# False    83622
# True      1264
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_1_Symptoms
# --------------------------------------------------
# diag_1_Symptoms
# False    78770
# True      6116
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Circulatory
# --------------------------------------------------
# diag_2_Circulatory
# False    58905
# True     25981
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Digestive
# --------------------------------------------------
# diag_2_Digestive
# False    81483
# True      3403
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Endocrine_Diabetes
# --------------------------------------------------
# diag_2_Endocrine_Diabetes
# False    67566
# True     17320
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_External_Causes
# --------------------------------------------------
# diag_2_External_Causes
# False    84261
# True       625
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Genitourinary
# --------------------------------------------------
# diag_2_Genitourinary
# False    77949
# True      6937
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Infectious
# --------------------------------------------------
# diag_2_Infectious
# False    83192
# True      1694
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Injury
# --------------------------------------------------
# diag_2_Injury
# False    82883
# True      2003
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Mental
# --------------------------------------------------
# diag_2_Mental
# False    82739
# True      2147
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Musculoskeletal
# --------------------------------------------------
# diag_2_Musculoskeletal
# False    83468
# True      1418
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Neoplasms
# --------------------------------------------------
# diag_2_Neoplasms
# False    82704
# True      2182
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Nervous_System
# --------------------------------------------------
# diag_2_Nervous_System
# False    83955
# True       931
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Other
# --------------------------------------------------
# diag_2_Other
# False    84775
# True       111
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Pregnancy
# --------------------------------------------------
# diag_2_Pregnancy
# False    84544
# True       342
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Respiratory
# --------------------------------------------------
# diag_2_Respiratory
# False    76120
# True      8766
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Sensory
# --------------------------------------------------
# diag_2_Sensory
# False    84761
# True       125
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Skin
# --------------------------------------------------
# diag_2_Skin
# False    81791
# True      3095
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Supplementary
# --------------------------------------------------
# diag_2_Supplementary
# False    83456
# True      1430
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_2_Symptoms
# --------------------------------------------------
# diag_2_Symptoms
# False    81080
# True      3806
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Circulatory
# --------------------------------------------------
# diag_3_Circulatory
# False    60051
# True     24835
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Digestive
# --------------------------------------------------
# diag_3_Digestive
# False    81819
# True      3067
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Endocrine_Diabetes
# --------------------------------------------------
# diag_3_Endocrine_Diabetes
# False    63108
# True     21778
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_External_Causes
# --------------------------------------------------
# diag_3_External_Causes
# False    83830
# True      1056
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Genitourinary
# --------------------------------------------------
# diag_3_Genitourinary
# False    79386
# True      5500
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Infectious
# --------------------------------------------------
# diag_3_Infectious
# False    83265
# True      1621
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Injury
# --------------------------------------------------
# diag_3_Injury
# False    83253
# True      1633
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Mental
# --------------------------------------------------
# diag_3_Mental
# False    82322
# True      2564
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Musculoskeletal
# --------------------------------------------------
# diag_3_Musculoskeletal
# False    83312
# True      1574
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Neoplasms
# --------------------------------------------------
# diag_3_Neoplasms
# False    83263
# True      1623
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Nervous_System
# --------------------------------------------------
# diag_3_Nervous_System
# False    83633
# True      1253
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Other
# --------------------------------------------------
# diag_3_Other
# False    84019
# True       867
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Pregnancy
# --------------------------------------------------
# diag_3_Pregnancy
# False    84635
# True       251
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Respiratory
# --------------------------------------------------
# diag_3_Respiratory
# False    79059
# True      5827
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Sensory
# --------------------------------------------------
# diag_3_Sensory
# False    84682
# True       204
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Skin
# --------------------------------------------------
# diag_3_Skin
# False    82708
# True      2178
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Supplementary
# --------------------------------------------------
# diag_3_Supplementary
# False    81861
# True      3025
# Name: count, dtype: int64
#
#
# ==================================================
# Column: diag_3_Symptoms
# --------------------------------------------------
# diag_3_Symptoms
# False    81106
# True      3780
# Name: count, dtype: int64
#
#
# ==================================================
# Column: admission_source_id_17
# --------------------------------------------------
# admission_source_id_17
# False    79026
# True      5860
# Name: count, dtype: int64
#
#
# ==================================================
# Column: admission_source_id_2
# --------------------------------------------------
# admission_source_id_2
# False    84032
# True       854
# Name: count, dtype: int64
#
#
# ==================================================
# Column: admission_source_id_20
# --------------------------------------------------
# admission_source_id_20
# False    84731
# True       155
# Name: count, dtype: int64
#
#
# ==================================================
# Column: admission_source_id_3
# --------------------------------------------------
# admission_source_id_3
# False    84789
# True        97
# Name: count, dtype: int64
#
#
# ==================================================
# Column: admission_source_id_4
# --------------------------------------------------
# admission_source_id_4
# False    82696
# True      2190
# Name: count, dtype: int64
#
#
# ==================================================
# Column: admission_source_id_5
# --------------------------------------------------
# admission_source_id_5
# False    84172
# True       714
# Name: count, dtype: int64
#
#
# ==================================================
# Column: admission_source_id_6
# --------------------------------------------------
# admission_source_id_6
# False    83026
# True      1860
# Name: count, dtype: int64
#
#
# ==================================================
# Column: admission_source_id_7
# --------------------------------------------------
# admission_source_id_7
# True     49476
# False    35410
# Name: count, dtype: int64

# %% [markdown]
# ## Step 1 — Prepare Data

# %%
TARGET = 'readmitted'

X = df_c.drop(columns=[TARGET])
y = df_c[TARGET]

# XGBoost rejects feature names containing '[', ']', or '<'
X.columns = (
    X.columns
     .str.replace('[', '', regex=False)
     .str.replace(']', '', regex=False)
     .str.replace('<', 'lt', regex=False)
)

bool_cols = X.select_dtypes(include='bool').columns
X[bool_cols] = X[bool_cols].astype('int8')
X = X.select_dtypes(include=[np.number])

# Drop columns with fewer than 300 positive samples — too sparse to learn from
sparse_cols = [c for c in X.columns if X[c].sum() < 300]
X = X.drop(columns=sparse_cols)
print(f'Dropped {len(sparse_cols)} sparse columns: {sparse_cols}')

print(f'Feature matrix shape : {X.shape}')
print(f'Class distribution   :')
print(y.value_counts().rename({0: 'No Readmit (0)',
                                 1: '>30 Days (1)',
                                 2: '<30 Days (2)'}))
# Out:
# Dropped 8 sparse columns: ['age_0-10)', 'diag_1_Sensory', 'diag_2_Other', 'diag_2_Sensory', 'diag_3_Pregnancy', 'diag_3_Sensory', 'admission_source_id_20', 'admission_source_id_3']
# Feature matrix shape : (84886, 88)
# Class distribution   :
# readmitted
# No Readmit (0)    44772
# >30 Days (1)      30442
# <30 Days (2)       9672
# Name: count, dtype: int64

# %% [markdown]
# ## Step 1b — Feature Selection
#
# Three complementary filter-based methods are applied:
#
# **1. Correlation-based removal (manual):** `admission_type_id` and `num_procedures` were dropped after the correlation matrix showed near-zero correlation with `readmitted` (|r| < 0.02).
#
# **2. Sparse column drop:** Dummy columns whose positive-class count is below 300 out of ~93,000 rows carry no reliable signal and are removed (e.g. `age_[0-10)` with only 98 rows).
#
# **3. Variance Threshold (filter method):** Removes near-constant features where one value dominates ≥ 99% of rows — these add noise without discriminative power.
#
# XGBoost does its own internal embedded feature selection via tree splits, so aggressive wrapper/MI methods are not needed and were found empirically to reduce test accuracy.

# %%
from sklearn.feature_selection import VarianceThreshold

vt = VarianceThreshold(threshold=0.99 * (1 - 0.99))
vt.fit(X)

low_var_cols = X.columns[~vt.get_support()].tolist()
X = X[X.columns[vt.get_support()]]

print(f'Variance Threshold removed {len(low_var_cols)} near-constant features:')
for c in low_var_cols:
    print(f'  - {c}')
print(f'\nFinal feature matrix shape: {X.shape}')

from sklearn.feature_selection import mutual_info_classif

mi_scores = mutual_info_classif(X, y, random_state=42)
mi_series = pd.Series(mi_scores, index=X.columns).sort_values(ascending=False).head(25)

fig, ax = plt.subplots(figsize=(10, 8))
fig.patch.set_facecolor('#1c1c1c')
ax.set_facecolor('#242424')
mi_series[::-1].plot(kind='barh', ax=ax, color='#00e5ff')
ax.set_title('Top 25 Features by Mutual Information Score', color='white', fontsize=13)
ax.set_xlabel('MI Score', color='white')
ax.tick_params(colors='white')
plt.tight_layout()
plt.savefig('mi_scores_XGB.png', facecolor='#1c1c1c')
plt.show()
print('Top 5 features by MI:', mi_series.head(5).index.tolist())
# Out:
# Variance Threshold removed 8 near-constant features:
#   - age_10-20)
#   - race_Asian
#   - discharge_group_Hospice
#   - diag_1_Nervous_System
#   - diag_1_Pregnancy
#   - diag_2_External_Causes
#   - diag_2_Pregnancy
#   - admission_source_id_5
#
# Final feature matrix shape: (84886, 80)
# Top 5 features by MI: ['number_inpatient', 'discharge_group_Death', 'number_emergency', 'admission_source_id_7', 'race_Caucasian']

# %% [markdown]
# ## Step 2 — Train / Test Split (80 / 20)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

print(f'Train size : {X_train.shape[0]:,} rows')
print(f'Test  size : {X_test.shape[0]:,} rows')
print(f'\nClass distribution (train):')
print(y_train.value_counts().rename({0:'No Readmit',1:'>30 Days',2:'<30 Days'}))
# Out:
# Train size : 67,908 rows
# Test  size : 16,978 rows
#
# Class distribution (train):
# readmitted
# No Readmit    35817
# >30 Days      24353
# <30 Days       7738
# Name: count, dtype: int64

# %% [markdown]
# ## Step 3 — Scale Continuous Features

# %%
# Only scale the continuous columns that survived feature selection
candidate_num_cols = ['time_in_hospital', 'num_lab_procedures',
                      'num_medications', 'number_outpatient', 'number_emergency',
                      'number_inpatient', 'number_diagnoses']
num_cols = [c for c in candidate_num_cols if c in X_train.columns]
print(f'Scaling {len(num_cols)} continuous columns: {num_cols}')

scaler = StandardScaler()

X_train_scaled = X_train.copy()
X_test_scaled  = X_test.copy()

X_train_scaled.loc[:, num_cols] = scaler.fit_transform(X_train[num_cols])
X_test_scaled.loc[:, num_cols]  = scaler.transform(X_test[num_cols])
# Out:
# Scaling 7 continuous columns: ['time_in_hospital', 'num_lab_procedures', 'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'number_diagnoses']
# /tmp/ipykernel_3420/67939420.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.89884138  0.79288305 -0.82215161 ... -1.3604965  -0.28380672
#   0.79288305]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_train_scaled.loc[:, num_cols] = scaler.fit_transform(X_train[num_cols])
# /tmp/ipykernel_3420/67939420.py:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.3604965  -0.28380672 -0.28380672 ... -2.43718627  0.79288305
#  -1.89884138]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   X_test_scaled.loc[:, num_cols]  = scaler.transform(X_test[num_cols])

# %%
best_xgb = XGBClassifier(
    objective='multi:softprob',
    num_class=3,
    eval_metric='mlogloss',
    random_state=42,
    n_jobs=-1,
    subsample=0.6,
    n_estimators=200,
    min_child_weight=3,
    max_depth=4,
    learning_rate=0.1,
    gamma=0.3,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=2.0,
)

best_xgb.fit(X_train_scaled, y_train)
print('Model trained with regularized params.')
# Out:
# Model trained with regularized params.

# %%
import joblib
import json

best_params = {
    'subsample': 0.6,
    'n_estimators': 200,
    'min_child_weight': 3,
    'max_depth': 4,
    'learning_rate': 0.1,
    'gamma': 0.3,
    'colsample_bytree': 0.8,
    'reg_alpha': 0.1,
    'reg_lambda': 2.0
}

joblib.dump(best_xgb, 'best_xgb_model.pkl')

with open('best_xgb_params.json', 'w') as f:
    json.dump(best_params, f, indent=4)

joblib.dump(scaler, 'scaler.pkl')

print(' Saved: best_xgb_model.pkl')
print(' Saved: best_xgb_params.json')
print(' Saved: scaler.pkl')
# Out:
#  Saved: best_xgb_model.pkl
#  Saved: best_xgb_params.json
#  Saved: scaler.pkl

# %%
for name, (X_eval, y_eval) in [('Training', (X_train_scaled, y_train)),
                                 ('Testing',  (X_test_scaled,  y_test))]:
    y_pred = best_xgb.predict(X_eval)
    print(f"\n{'='*40}")
    print(f"Phase: {name}")
    print(f"Accuracy:  {accuracy_score(y_eval, y_pred):.3f}")
    print(f"Precision: {precision_score(y_eval, y_pred, average='weighted'):.3f}")
    print(f"Recall:    {recall_score(y_eval, y_pred, average='weighted'):.3f}")
    print(f"F1 Score:  {f1_score(y_eval, y_pred, average='weighted'):.3f}")
# Out:
# ========================================
# Phase: Training
# Accuracy:  0.590
# Precision: 0.583
# Recall:    0.590
# F1 Score:  0.544
#
# ========================================
# Phase: Testing
# Accuracy:  0.578
# Precision: 0.560
# Recall:    0.578
# F1 Score:  0.529

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax, (name, (X_eval, y_eval)) in zip(axes, [
    ('Training', (X_train_scaled, y_train)),
    ('Testing',  (X_test_scaled,  y_test))
]):
    cm = confusion_matrix(y_eval, best_xgb.predict(X_eval))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax)
    ax.set_title(f'XGB {name} Confusion Matrix')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')
plt.tight_layout()
plt.savefig('confusion_matrix_XGB.png')
plt.show()

# %% [markdown]
# ## Learning Curve & Validation Curve

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, val_scores = learning_curve(
    XGBClassifier(
        objective='multi:softprob', num_class=3, eval_metric='mlogloss',
        subsample=0.6, n_estimators=200, min_child_weight=3, max_depth=4,
        learning_rate=0.1, gamma=0.3, colsample_bytree=0.8,
        reg_alpha=0.1, reg_lambda=2.0,
        random_state=42, n_jobs=-1
    ),
    X_train_scaled, y_train,
    cv=5,
    scoring='accuracy',
    train_sizes=np.linspace(0.1, 1.0, 8),
    n_jobs=-1
)

train_mean = train_scores.mean(axis=1)
train_std  = train_scores.std(axis=1)
val_mean   = val_scores.mean(axis=1)
val_std    = val_scores.std(axis=1)

fig, ax = plt.subplots(figsize=(10, 6))
fig.patch.set_facecolor('#1c1c1c')
ax.set_facecolor('#242424')

ax.plot(train_sizes, train_mean, 'o-', color='#00e5ff', label='Training score')
ax.fill_between(train_sizes, train_mean - train_std,
                train_mean + train_std, alpha=0.15, color='#00e5ff')

ax.plot(train_sizes, val_mean, 'o-', color='#ff4081', label='Cross-validation score')
ax.fill_between(train_sizes, val_mean - val_std,
                val_mean + val_std, alpha=0.15, color='#ff4081')

ax.set_title('Learning Curve — XGBoost (Regularized)', color='white', fontsize=14)
ax.set_xlabel('Training Set Size', color='white')
ax.set_ylabel('Accuracy', color='white')
ax.tick_params(colors='white')
ax.grid(True, linestyle=':', alpha=0.3, color='white')
legend = ax.legend(facecolor='#242424', edgecolor='white')
plt.setp(legend.get_texts(), color='white')
plt.tight_layout()
plt.savefig('learning_curve_XGB.png', facecolor='#1c1c1c')
plt.show()

print(f'Final training accuracy : {train_mean[-1]:.3f} ± {train_std[-1]:.3f}')
print(f'Final CV accuracy       : {val_mean[-1]:.3f} ± {val_std[-1]:.3f}')
print(f'Bias-variance gap       : {train_mean[-1] - val_mean[-1]:.3f}')
# Out:
# Final training accuracy : 0.594 ± 0.001
# Final CV accuracy       : 0.577 ± 0.002
# Bias-variance gap       : 0.017

# %%
from sklearn.model_selection import validation_curve

param_range = [2, 3, 4, 5, 6, 7, 8, 10]

train_scores_v, val_scores_v = validation_curve(
    XGBClassifier(
        objective='multi:softprob', num_class=3, eval_metric='mlogloss',
        subsample=0.6, n_estimators=200, min_child_weight=3,
        learning_rate=0.1, gamma=0.3, colsample_bytree=0.8,
        reg_alpha=0.1, reg_lambda=2.0,
        random_state=42, n_jobs=-1
    ),
    X_train_scaled, y_train,
    param_name='max_depth',
    param_range=param_range,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

train_mean_v = train_scores_v.mean(axis=1)
train_std_v  = train_scores_v.std(axis=1)
val_mean_v   = val_scores_v.mean(axis=1)
val_std_v    = val_scores_v.std(axis=1)

fig, ax = plt.subplots(figsize=(10, 6))
fig.patch.set_facecolor('#1c1c1c')
ax.set_facecolor('#242424')

ax.plot(param_range, train_mean_v, 'o-', color='#00e5ff', label='Training score')
ax.fill_between(param_range, train_mean_v - train_std_v,
                train_mean_v + train_std_v, alpha=0.15, color='#00e5ff')

ax.plot(param_range, val_mean_v, 'o-', color='#ff4081', label='Cross-validation score')
ax.fill_between(param_range, val_mean_v - val_std_v,
                val_mean_v + val_std_v, alpha=0.15, color='#ff4081')

ax.axvline(x=4, color='#ffd600', linestyle='--', linewidth=1.5, label='Chosen depth = 4')

ax.set_title('Validation Curve — max_depth (XGBoost)', color='white', fontsize=14)
ax.set_xlabel('max_depth', color='white')
ax.set_ylabel('Accuracy', color='white')
ax.set_xticks(param_range)
ax.tick_params(colors='white')
ax.grid(True, linestyle=':', alpha=0.3, color='white')
legend = ax.legend(facecolor='#242424', edgecolor='white')
plt.setp(legend.get_texts(), color='white')
plt.tight_layout()
plt.savefig('validation_curve_XGB.png', facecolor='#1c1c1c')
plt.show()

best_depth = param_range[val_mean_v.argmax()]
print(f'Best max_depth by CV    : {best_depth}')
print(f'CV accuracy at depth {best_depth}  : {val_mean_v.max():.3f}')
# Out:
# Best max_depth by CV    : 6
# CV accuracy at depth 6  : 0.577

# %%
for name, (X_eval, y_eval) in [('Training', (X_train_scaled, y_train)),
                                 ('Testing',  (X_test_scaled,  y_test))]:
    y_prob = best_xgb.predict_proba(X_eval)
    auc = roc_auc_score(y_eval, y_prob, multi_class='ovr')
    print(f"AUC {name}: {auc:.3f}")
# Out:
# AUC Training: 0.699
# AUC Testing: 0.669

# %%
CLASS_NAMES = ['No Readmit', '>30 Days', '<30 Days']

explainer   = shap.TreeExplainer(best_xgb)

shap_values = explainer.shap_values(X_test_scaled)

for cls_idx, cls_name in enumerate(CLASS_NAMES):
    plt.figure()
    shap.summary_plot(
        shap_values[:, :, cls_idx], X_test_scaled,
        plot_type='dot', show=False
    )
    plt.title(f'SHAP Beeswarm — {cls_name}', pad=14)
    plt.tight_layout()
    plt.savefig(f'shap_summary_class{cls_idx}_XGB.png')
    plt.show()

plt.figure()
shap.summary_plot(
    shap_values,
    X_test_scaled,
    plot_type='bar', show=False,
    class_names=CLASS_NAMES
)
plt.tight_layout()
plt.savefig('shap_bar_XGB.png')
plt.show()

# %%
CLASS_NAMES = ['No Readmit', '>30 Days', '<30 Days']
y_pred_test  = best_xgb.predict(X_test_scaled)

for i in range(4):
    pred_cls = int(y_pred_test[i])
    plt.figure()
    shap.waterfall_plot(
        shap.Explanation(
            values       = shap_values[i, :, pred_cls],
            base_values  = explainer.expected_value[pred_cls],
            data         = X_test_scaled.iloc[i],
            feature_names= X_test_scaled.columns.tolist()
        ), show=False
    )
    plt.title(f'Local Explanation — Instance {i+1}  '
              f'(Predicted: {CLASS_NAMES[pred_cls]})')
    plt.tight_layout()
    plt.savefig(f'shap_local_instance_{i+1}.png')
    plt.show()
